# %%
w = np.zeros((2,1)) #pesos iniciales
w
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 w = np.zeros((2,1)) #pesos iniciales
#       2 w
#
# NameError: name 'np' is not defined

# %%
X = (X - X.mean()) / X.std() #normalizacion de los datos
y = (y - y.mean()) / y.std() #normalizacion de los datos
x = np.array ([[1)

# %%
lr = 0.1 #learning rate

# %%
epochs = 100 #cuantos pasos realizar (epocas)
for epoch in range(epochs): #ciclo for para recorrer las epocas
    lse = 0.5 * (y - phi @ w)**2 #gradiente
    gra = phi.T @ (y - phi @ w) #gradiente
    w = w + lr * gra #actualizacion de los pesos
w

# %%
phi =np.array ([np.ones(len(X)), X]).T
phi

# %%
w = np.array(([0],[0]))
lr = 0.1
w, lr

# %%
#errors = []
epochs = 100
for epoch in range(epochs):
    lse = 0.5 * (b - phi @ w)**2
    gra = phi.T @ (b - phi @ w)
    w = w + lr * grad #stochastic gradient descent 

    #errors.append(lse.sum())
w
